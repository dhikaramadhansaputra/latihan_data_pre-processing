# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Latihan data cleaning\Hospital data in Indonesia\(Raw data) Hospital_Indonesia_datasets.csv", delimiter=';')
df
# Out:
#            id                                               nama  \
# 0     1110053                                RS Arun Lhokseumawe
# 1     1106014                                    RS Umum Fandika
# 2     1171110                             RS Umum Daerah Meuraxa
# 3     1171163              RS Gigi Mulut Universitas Syiah Kuala
# 4     1102027                   RS Umum Daerah Kota Subulussalam
# ...       ...                                                ...
# 3150  9232011                             RS Umum Daerah Er Dabi
# 3151  9231002  RS Umum Daerah Lukas Enembe Kab. Memberamo Tengah
# 3152  9201046            RS Tk. IV 17.07.01 Jenderal LB Moerdani
# 3153  9212027                            RS TNI AD Tk. IV Timika
# 3154  9271023                                    RS Umum Abepura
#
#               propinsi                kab  \
# 0                 Aceh   Kota Lhokseumawe
# 1                 Aceh        Aceh Tengah
# 2                 Aceh    Kota Banda Aceh
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# id                    0
# nama                  0
# propinsi              0
# kab                   0
# alamat                0
# jenis                 0
# kelas                 0
# status_blu            0
# kepemilikan           0
# total_tempat_tidur    0
# total_layanan         0
# total_tenaga_kerja    0
# dtype: int64

# %%
df['jenis'].drop_duplicates()
# Out:
# 0                        Rumah Sakit Umum
# 3       Rumah Sakit Khusus Gigi dan Mulut
# 10        Rumah Sakit Khusus Ibu dan Anak
# 58                Rumah Sakit Khusus Jiwa
# 91               Rumah Sakit Khusus Bedah
# 97                Rumah Sakit Khusus Mata
# 189               Rumah Sakit Khusus Paru
# 220             Rumah Sakit Khusus Ginjal
# 326             Rumah Sakit Khusus Stroke
# 771             Rumah Sakit Khusus THT-KL
# 789             Rumah Sakit Khusus Kanker
# 795            Rumah Sakit Khusus Infeksi
# 806                          021-26071997
# 834            Rumah Sakit Khusus Jantung
# 846               Rumah Sakit Khusus Otak
# 859       Rumah Sakit Ketergantungan Obat
# 876          Rumah Sakit Khusus Orthopedi
# 910                     RS Kapal/Bergerak
# 1403                                    2
# 1746
# 3114                                    -
# Name: jenis, dtype: object

# %%
df[df['jenis'] == '021-26071997']
# Out:
# Empty DataFrame
# Columns: [id, nama, propinsi, kab, alamat, jenis, kelas, status_blu, kepemilikan, total_tempat_tidur, total_layanan, total_tenaga_kerja]
# Index: []

# %%
df = df[df['id'] != 3101002]

# %%
df.head(50)
# Out:
#          id                                              nama propinsi  \
# 0   1110053                               RS Arun Lhokseumawe     Aceh
# 1   1106014                                   RS Umum Fandika     Aceh
# 2   1171110                            RS Umum Daerah Meuraxa     Aceh
# 3   1171163             RS Gigi Mulut Universitas Syiah Kuala     Aceh
# 4   1102027                  RS Umum Daerah Kota Subulussalam     Aceh
# 5   1106013                 RS Umum Daerah Datu Beru Takengon     Aceh
# 6   1109028                                     RS Umum Mufid     Aceh
# 7   1174022                      RS Umum Metro Medical Center     Aceh
# 8   1117025  RS Umum Daerah Muyang Kute Redelong Bener Meriah     Aceh
# 9   1106025                            RS Gayo Medical Centre     Aceh
# 10  1104013                     RS Ibu dan Anak Keluarga Desa     Aceh
# 11  1105078                              RS Umum Graha Bunda      Aceh
# ...
