# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Latihan data cleaning\Hospital data in Indonesia\dataset\(Raw data) Hospital_Indonesia_datasets.csv", delimiter=';')
df
# Out:
#            id                                               nama  \
# 0     1110053                                RS Arun Lhokseumawe
# 1     1106014                                    RS Umum Fandika
# 2     1171110                             RS Umum Daerah Meuraxa
# 3     1171163              RS Gigi Mulut Universitas Syiah Kuala
# 4     1102027                   RS Umum Daerah Kota Subulussalam
# ...       ...                                                ...
# 3150  9232011                             RS Umum Daerah Er Dabi
# 3151  9231002  RS Umum Daerah Lukas Enembe Kab. Memberamo Tengah
# 3152  9201046            RS Tk. IV 17.07.01 Jenderal LB Moerdani
# 3153  9212027                            RS TNI AD Tk. IV Timika
# 3154  9271023                                    RS Umum Abepura
#
#               propinsi                kab  \
# 0                 Aceh   Kota Lhokseumawe
# 1                 Aceh        Aceh Tengah
# 2                 Aceh    Kota Banda Aceh
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# id                    0
# nama                  0
# propinsi              0
# kab                   0
# alamat                0
# jenis                 0
# kelas                 0
# status_blu            0
# kepemilikan           0
# total_tempat_tidur    0
# total_layanan         0
# total_tenaga_kerja    0
# dtype: int64

# %%
df['jenis'].drop_duplicates()
# Out:
# 0                        Rumah Sakit Umum
# 3       Rumah Sakit Khusus Gigi dan Mulut
# 10        Rumah Sakit Khusus Ibu dan Anak
# 58                Rumah Sakit Khusus Jiwa
# 91               Rumah Sakit Khusus Bedah
# 97                Rumah Sakit Khusus Mata
# 189               Rumah Sakit Khusus Paru
# 220             Rumah Sakit Khusus Ginjal
# 326             Rumah Sakit Khusus Stroke
# 771             Rumah Sakit Khusus THT-KL
# 789             Rumah Sakit Khusus Kanker
# 795            Rumah Sakit Khusus Infeksi
# 806                          021-26071997
# 834            Rumah Sakit Khusus Jantung
# 846               Rumah Sakit Khusus Otak
# 859       Rumah Sakit Ketergantungan Obat
# 876          Rumah Sakit Khusus Orthopedi
# 910                     RS Kapal/Bergerak
# 1403                                    2
# 1746
# 3114                                    -
# Name: jenis, dtype: object

# %%
df[df['jenis'] == '021-26071997']
# Out:
#           id                             nama     propinsi               kab  \
# 806  3101002  RS Umum Daerah Kepulauan Seribu  DKI Jakarta  Kepulauan Seribu
#
#                                                 alamat         jenis  \
# 806  Pulau Pramuka Rt.001 RW.004, Kelurahan : Pulau...  021-26071997
#
#                 kelas status_blu kepemilikan  total_tempat_tidur  \
# 806  Rumah Sakit Umum          D        BLUD                1966
#
#      total_layanan  total_tenaga_kerja
# 806             50                  24

# %%
df = df[df['id'] != 3101002]

# %%
df.head(50)
# Out:
#          id                                              nama propinsi  \
# 0   1110053                               RS Arun Lhokseumawe     Aceh
# 1   1106014                                   RS Umum Fandika     Aceh
# 2   1171110                            RS Umum Daerah Meuraxa     Aceh
# 3   1171163             RS Gigi Mulut Universitas Syiah Kuala     Aceh
# 4   1102027                  RS Umum Daerah Kota Subulussalam     Aceh
# 5   1106013                 RS Umum Daerah Datu Beru Takengon     Aceh
# 6   1109028                                     RS Umum Mufid     Aceh
# 7   1174022                      RS Umum Metro Medical Center     Aceh
# 8   1117025  RS Umum Daerah Muyang Kute Redelong Bener Meriah     Aceh
# 9   1106025                            RS Gayo Medical Centre     Aceh
# 10  1104013                     RS Ibu dan Anak Keluarga Desa     Aceh
# 11  1105078                              RS Umum Graha Bunda      Aceh
# ...

# %%
df['kelas'].drop_duplicates()
# Out:
# 0                             C
# 1                             D
# 2                             B
# 25                    D PRATAMA
# 47                            A
# 442            Belum Ditetapkan
# 1403           Rumah Sakit Umum
# 1746    Rumah Sakit Khusus Jiwa
# Name: kelas, dtype: object

# %%
df[df['kelas'] == 'Rumah Sakit Umum']
# Out:
#            id                                    nama     propinsi  \
# 1403  3310015  RS Umum Pusat Dr. Soeradji Tirtonegoro  Jawa Tengah
# 3114  9228002                   RS Umum Daerah Kawera        Papua
#
#                  kab                                    alamat jenis  \
# 1403          Klaten  Jl. KRT. Suraji Tirtonegoro No.1, Klaten     2
# 3114  Mamberamo Raya             Jln. Demianus Kyeuw-kyeuw, SH     -
#
#                  kelas status_blu   kepemilikan  total_tempat_tidur  \
# 1403  Rumah Sakit Umum          A           BLU               30343
# 3114  Rumah Sakit Umum  D PRATAMA  Non BLU/BLUD                1220
#
#       total_layanan  total_tenaga_kerja
# 1403            419                 141
# 3114             50                  20

# %%
df[df['id'] == 3310015]
# Out:
#            id                                    nama     propinsi     kab  \
# 1403  3310015  RS Umum Pusat Dr. Soeradji Tirtonegoro  Jawa Tengah  Klaten
#
#                                         alamat jenis             kelas  \
# 1403  Jl. KRT. Suraji Tirtonegoro No.1, Klaten     2  Rumah Sakit Umum
#
#      status_blu kepemilikan  total_tempat_tidur  total_layanan  \
# 1403          A         BLU               30343            419
#
#       total_tenaga_kerja
# 1403                 141

# %%
df.loc[df['id'] == 3310015, 'jenis'] = 'Rumah Sakit Umum'
df.loc[df['id'] == 3310015]
# Out:
#            id                                    nama     propinsi     kab  \
# 1403  3310015  RS Umum Pusat Dr. Soeradji Tirtonegoro  Jawa Tengah  Klaten
#
#                                         alamat             jenis  \
# 1403  Jl. KRT. Suraji Tirtonegoro No.1, Klaten  Rumah Sakit Umum
#
#                  kelas status_blu kepemilikan  total_tempat_tidur  \
# 1403  Rumah Sakit Umum          A         BLU               30343
#
#       total_layanan  total_tenaga_kerja
# 1403            419                 141

# %%
df.loc[df['id'] == 3310015, 'kelas'] = 'A'
df.loc[df['id'] == 3310015, 'status_blu'] = 'BLU'
df.loc[df['id'] == 3310015, 'kepemilikan'] = 'Tidak Diketahui'
df.loc[df['id'] == 3310015]
# Out:
#            id                                    nama     propinsi     kab  \
# 1403  3310015  RS Umum Pusat Dr. Soeradji Tirtonegoro  Jawa Tengah  Klaten
#
#                                         alamat             jenis kelas  \
# 1403  Jl. KRT. Suraji Tirtonegoro No.1, Klaten  Rumah Sakit Umum     A
#
#      status_blu      kepemilikan  total_tempat_tidur  total_layanan  \
# 1403        BLU  Tidak Diketahui               30343            419
#
#       total_tenaga_kerja
# 1403                 141

# %%
df.loc[df['id'] == 9228002, 'jenis'] = 'Rumah Sakit Umum'
df.loc[df['id'] == 9228002, 'kelas'] = 'D PRATAMA'
df.loc[df['id'] == 9228002, 'status_blu'] = 'Non BLU/BLUD'
df.loc[df['id'] == 9228002, 'kepemilikan'] = 'Tidak Diketahui'

# %%
df.loc[df['id'] == 9228002]
# Out:
#            id                   nama propinsi             kab  \
# 3114  9228002  RS Umum Daerah Kawera    Papua  Mamberamo Raya
#
#                                alamat             jenis      kelas  \
# 3114    Jln. Demianus Kyeuw-kyeuw, SH  Rumah Sakit Umum  D PRATAMA
#
#         status_blu      kepemilikan  total_tempat_tidur  total_layanan  \
# 3114  Non BLU/BLUD  Tidak Diketahui                1220             50
#
#       total_tenaga_kerja
# 3114                  20

# %%
df['kepemilikan'].drop_duplicates()
# Out:
# 0             SWASTA/LAINNYA
# 2                     Pemkot
# 3           Kementerian Lain
# 5                     Pemkab
# 6                 Perusahaan
# 11         Organisasi Sosial
# 13                     POLRI
# 16                    TNI AD
# 24                    TNI AL
# 31                      BUMN
# 43                   Pemprop
# 53                Perorangan
# 89       Organisasi Katholik
# 92      Organisasi Protestan
# 159                  Kemkes
# 232                   TNI AU
# 288        Organisasi Islam
# 801         Organisasi Budha
# 1403         Tidak Diketahui
# 1746            Non BLU/BLUD
# 2348        Organisasi Hindu
# Name: kepemilikan, dtype: object

# %%
df[~df['total_tempat_tidur'].astype(str).str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [id, nama, propinsi, kab, alamat, jenis, kelas, status_blu, kepemilikan, total_tempat_tidur, total_layanan, total_tenaga_kerja]
# Index: []

# %%
df['total_layanan'].drop_duplicates()
# Out:
# 0        36
# 1        15
# 2        77
# 3        24
# 4        34
# 5        80
# 6        64
# 7        38
# 8        35
# 9        56
# 10       28
# 11       26
# 12       84
# 13       23
# 14       68
# 16       82
# 17       30
# 18       33
# 19       22
# 20       60
# 24       17
# 25        3
# 26       65
# 27       25
# 28       13
# 31       21
# 34       39
# 35       47
# 36       44
# 38       11
# 39       20
# 42       96
# 43       29
# 44       32
# 45       18
# 46       16
# 47      141
# 49       31
# 57       54
# 59       75
# 62       14
# 64       27
# 66      106
# 82       12
# 86        5
# 88       61
# 90        4
# 92       57
# 94       53
# 101      42
# 107      10
# 109      55
# 112      81
# 113       8
# 118     101
# 122      19
# 123      58
# 132     134
# 138      98
# 144      66
# 149      67
# 159     158
# 174     136
# 176      78
# 179      72
# 188      46
# 190       9
# 191      40
# 193      73
# 195      37
# 197      90
# ...

# %%
df[~df['total_layanan'].astype(str).str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [id, nama, propinsi, kab, alamat, jenis, kelas, status_blu, kepemilikan, total_tempat_tidur, total_layanan, total_tenaga_kerja]
# Index: []

# %%
df['total_tenaga_kerja']
# Out:
# 0        328
# 1         45
# 2        487
# 3          0
# 4        537
# 5        470
# 6        208
# 7        128
# 8        199
# 9          0
# 10         3
# 11       315
# 12      1178
# 13       147
# 14       515
# 15       262
# 16       442
# 17        91
# 18       533
# 19       119
# 20       303
# 21       151
# 22         0
# 23       406
# 24        20
# 25         0
# 26      1169
# 27       801
# 28        18
# 29        67
# 30       640
# 31        49
# 32         0
# 33       123
# 34       148
# 35       636
# 36       577
# 37       101
# 38         0
# 39         0
# 40       480
# 41        80
# 42         0
# 43       453
# 44       566
# 45        66
# 46       812
# 47      2039
# 48        20
# 49       196
# 50       167
# 51       261
# 52       289
# 53        13
# 54        53
# 55       493
# 56      1949
# 57       243
# 58       541
# 59       159
# 60      1100
# 61        60
# 62        63
# 63        36
# 64       221
# 65        55
# ...

# %%
len(df[df['total_tenaga_kerja'] == 0])
# Out:
# 357

# %%
df[df['total_tenaga_kerja'] == 0].head(10)
# Out:
#          id                                      nama propinsi  \
# 3   1171163     RS Gigi Mulut Universitas Syiah Kuala     Aceh
# 9   1106025                    RS Gayo Medical Centre     Aceh
# 22  1113023                             RS Tanoh Gayo     Aceh
# 25  1103022  RS Umum Daerah Type D Pratama T. Cut Ali     Aceh
# 32  1111006          RS Umum Daerah dr. Muchtar Hasbi     Aceh
# 38  1111029                                  RS Zahra     Aceh
# 39  1103021                           RS Cahaya Sehat     Aceh
# 42  1171161                      RS Umum Cempaka Lima     Aceh
# 73  1109042                       RS Umum Harapan Ibu     Aceh
# 77  1108028                           RS Hermina Aceh     Aceh
#
#                 kab                                             alamat  \
# 3   Kota Banda Aceh  Jl. Prof A. Madjid Ibrahim I No. 5 Banda Aceh ...
# 9       Aceh Tengah    Jl. Paya Tumpi-Mandale, No. 126  Kec. Kebayakan
# ...

# %%
df.loc[df['total_tenaga_kerja'] == 0, 'total_tenaga_kerja'] = np.nan

# %%
df.loc[pd.isna(df['total_tenaga_kerja'])].head(10)
# Out:
#          id                                      nama propinsi  \
# 3   1171163     RS Gigi Mulut Universitas Syiah Kuala     Aceh
# 9   1106025                    RS Gayo Medical Centre     Aceh
# 22  1113023                             RS Tanoh Gayo     Aceh
# 25  1103022  RS Umum Daerah Type D Pratama T. Cut Ali     Aceh
# 32  1111006          RS Umum Daerah dr. Muchtar Hasbi     Aceh
# 38  1111029                                  RS Zahra     Aceh
# 39  1103021                           RS Cahaya Sehat     Aceh
# 42  1171161                      RS Umum Cempaka Lima     Aceh
# 73  1109042                       RS Umum Harapan Ibu     Aceh
# 77  1108028                           RS Hermina Aceh     Aceh
#
#                 kab                                             alamat  \
# 3   Kota Banda Aceh  Jl. Prof A. Madjid Ibrahim I No. 5 Banda Aceh ...
# 9       Aceh Tengah    Jl. Paya Tumpi-Mandale, No. 126  Kec. Kebayakan
# ...

# %%
len(df.loc[pd.isna(df['total_tenaga_kerja'])])
# Out:
# 357

# %%
df.drop(columns='alamat', inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2832\2598259742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='alamat', inplace=True)

# %% [markdown]
# RE-CHECK SEMUA

# %%
df.isnull().sum()
# Out:
# id                      0
# nama                    0
# propinsi                0
# kab                     0
# jenis                   0
# kelas                   0
# status_blu              0
# kepemilikan             0
# total_tempat_tidur      0
# total_layanan           0
# total_tenaga_kerja    357
# dtype: int64

# %%
df['nama'].drop_duplicates()
# Out:
# 0                                     RS Arun Lhokseumawe
# 1                                         RS Umum Fandika
# 2                                  RS Umum Daerah Meuraxa
# 3                   RS Gigi Mulut Universitas Syiah Kuala
# 4                        RS Umum Daerah Kota Subulussalam
# 5                       RS Umum Daerah Datu Beru Takengon
# 6                                           RS Umum Mufid
# 7                            RS Umum Metro Medical Center
# 8        RS Umum Daerah Muyang Kute Redelong Bener Meriah
# 9                                  RS Gayo Medical Centre
# 10                          RS Ibu dan Anak Keluarga Desa
# 11                                   RS Umum Graha Bunda
# 12                      RS Umum Daerah Dr. Fauziah Bireun
# 13                              RS Bhayangkara Banda Aceh
# 14                     RS Umum Daerah Dr. H. Yulidin Away
# 15                    RS Umum Daerah Kabupaten Aceh Besar
# ...

# %%
df['propinsi'].drop_duplicates()
# Out:
# 0                            Aceh
# 79                 Sumatera Utara
# 281                Sumatera Barat
# 359                          Riau
# 440                         Jambi
# 482              Sumatera Selatan
# 569                      Bengkulu
# 595                       Lampung
# 675     Kepulauan Bangka Belitung
# 703                Kepulauan Riau
# 738                   DKI Jakarta
# 926                    Jawa Barat
# 1347                  Jawa Tengah
# 1702                   Yogyakarta
# 1782                   Jawa Timur
# 2214                       Banten
# 2343                         Bali
# 2422          Nusa Tenggara Barat
# 2468          Nusa Tenggara Timur
# 2530             Kalimantan Barat
# 2588            Kalimantan Tengah
# 2620           Kalimantan Selatan
# 2670             Kalimantan Timur
# 2728             Kalimantan Utara
# 2745               Sulawesi Utara
# 2803              Sulawesi Tengah
# 2842             Sulawesi Selatan
# ...

# %%
df['kab'].drop_duplicates()
# Out:
# 0                       Kota Lhokseumawe
# 1                            Aceh Tengah
# 2                        Kota Banda Aceh
# 4                      Kota Subulussalam
# 6                                  Pidie
# 8                           Bener Meriah
# 10                         Aceh Tenggara
# 11                            Aceh Timur
# 12                               Bireuen
# 14                          Aceh Selatan
# 15                            Aceh Besar
# 18                              Simeulue
# 22                             Gayo Lues
# 23                             Aceh Jaya
# 24                           Kota Sabang
# 26                           Kota Langsa
# 31                          Aceh Tamiang
# 32                            Aceh Utara
# 36                            Nagan Raya
# 44                          Aceh Singkil
# 46                            Aceh Barat
# 60                       Aceh Barat Daya
# 70                            Pidie Jaya
# ...

# %%
df['jenis'].drop_duplicates()
# Out:
# 0                        Rumah Sakit Umum
# 3       Rumah Sakit Khusus Gigi dan Mulut
# 10        Rumah Sakit Khusus Ibu dan Anak
# 58                Rumah Sakit Khusus Jiwa
# 91               Rumah Sakit Khusus Bedah
# 97                Rumah Sakit Khusus Mata
# 189               Rumah Sakit Khusus Paru
# 220             Rumah Sakit Khusus Ginjal
# 326             Rumah Sakit Khusus Stroke
# 771             Rumah Sakit Khusus THT-KL
# 789             Rumah Sakit Khusus Kanker
# 795            Rumah Sakit Khusus Infeksi
# 834            Rumah Sakit Khusus Jantung
# 846               Rumah Sakit Khusus Otak
# 859       Rumah Sakit Ketergantungan Obat
# 876          Rumah Sakit Khusus Orthopedi
# 910                     RS Kapal/Bergerak
# 1746
# Name: jenis, dtype: object

# %%
df['kelas'].drop_duplicates()
# Out:
# 0                             C
# 1                             D
# 2                             B
# 25                    D PRATAMA
# 47                            A
# 442            Belum Ditetapkan
# 1746    Rumah Sakit Khusus Jiwa
# Name: kelas, dtype: object

# %%
df[df['kelas'] == 'Rumah Sakit Khusus Jiwa']
# Out:
#            id                         nama    propinsi              kab jenis  \
# 1746  3471085  RS Khusus Jiwa Puri Nirmala  Yogyakarta  Kota Yogyakarta
#
#                         kelas status_blu   kepemilikan  total_tempat_tidur  \
# 1746  Rumah Sakit Khusus Jiwa          C  Non BLU/BLUD                1296
#
#       total_layanan  total_tenaga_kerja
# 1746             27                13.0

# %%
df.loc[df['id'] == 3471085, 'jenis'] = 'Rumah Sakit Khusus Jiwa'
df.loc[df['id'] == 3471085, 'kelas'] = 'C'
df.loc[df['id'] == 3471085, 'status_blu'] = 'Non BLU/BLUD'
df.loc[df['id'] == 3471085, 'kepemilikan'] = 'Tidak Diketahui'
df.loc[df['id'] == 3471085]
# Out:
#            id                         nama    propinsi              kab  \
# 1746  3471085  RS Khusus Jiwa Puri Nirmala  Yogyakarta  Kota Yogyakarta
#
#                         jenis kelas    status_blu      kepemilikan  \
# 1746  Rumah Sakit Khusus Jiwa     C  Non BLU/BLUD  Tidak Diketahui
#
#       total_tempat_tidur  total_layanan  total_tenaga_kerja
# 1746                1296             27                13.0

# %%
df['kepemilikan'].drop_duplicates()
# Out:
# 0             SWASTA/LAINNYA
# 2                     Pemkot
# 3           Kementerian Lain
# 5                     Pemkab
# 6                 Perusahaan
# 11         Organisasi Sosial
# 13                     POLRI
# 16                    TNI AD
# 24                    TNI AL
# 31                      BUMN
# 43                   Pemprop
# 53                Perorangan
# 89       Organisasi Katholik
# 92      Organisasi Protestan
# 159                  Kemkes
# 232                   TNI AU
# 288        Organisasi Islam
# 801         Organisasi Budha
# 1403         Tidak Diketahui
# 2348        Organisasi Hindu
# Name: kepemilikan, dtype: object

# %%
df[~df['total_tempat_tidur'].astype(str).str.isnumeric()]
# Out:
# Empty DataFrame
# Columns: [id, nama, propinsi, kab, jenis, kelas, status_blu, kepemilikan, total_tempat_tidur, total_layanan, total_tenaga_kerja]
# Index: []

# %%
df['total_tempat_tidur'].astype(str).str.isnumeric().drop_duplicates()
# Out:
# 0    True
# Name: total_tempat_tidur, dtype: bool

# %%
df['total_layanan'].astype(str).str.isnumeric().drop_duplicates()
# Out:
# 0    True
# Name: total_layanan, dtype: bool

# %%
df['total_tenaga_kerja'] = pd.to_numeric(df['total_tenaga_kerja'], errors='coerce').astype('Int64')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2832\273113511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_tenaga_kerja'] = pd.to_numeric(df['total_tenaga_kerja'], errors='coerce').astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3154 entries, 0 to 3154
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  3154 non-null   int64
#  1   nama                3154 non-null   object
#  2   propinsi            3154 non-null   object
#  3   kab                 3154 non-null   object
#  4   jenis               3154 non-null   object
#  5   kelas               3154 non-null   object
#  6   status_blu          3154 non-null   object
#  7   kepemilikan         3154 non-null   object
#  8   total_tempat_tidur  3154 non-null   int64
#  9   total_layanan       3154 non-null   int64
#  10  total_tenaga_kerja  2797 non-null   Int64
# dtypes: Int64(1), int64(3), object(7)
# memory usage: 298.8+ KB

# %% [markdown]
# CEK ULANG SELESAI

# %%
df.to_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Latihan data cleaning\Hospital data in Indonesia\dataset\clean data (hospital data in Indonesia).csv", index=False)
